# %% [markdown]
# Exploratory Data Analysis and Prediction of Alcohol-Related Road Accidents in Hungary Using Official Statistical Data

# %% [markdown]
# This project analyzes alcohol-related road accidents in Hungary using available data from the Hungarian Central Statistical Office. The analysis uses the following datasets: number of registered passenger vehicles, estimated number of alcohol-dependent individuals, total road accidents, road accidents involving intoxicated drivers.
#
# 1. An exploratory data analysis is applied to the data, to summarize the main statistical characteristics and trends. Descriptive statistics, visualizations, and correlation analysis are used to better understand how traffic volume and alcohol consumption indicators relate to accident patterns.
#
# 2. Based on these findings, a predictive model is developed using two variables to estimate the number of road accidents related to alcohol. The purpose of the model is to estimate how changes in vehicle ownership and alcohol-related indicators can help explain variations in drunk-driving accidents over time.
#
# 3. The results are interpreted to make conclusions regarding road safety and the potential societal factors influencing alcohol-related traffic incidents.
